# %% [markdown]
#  QSAR Modeling**
# This notebook demonstrates how to collect and preprocess bioactivity data from ChEMBL for QSAR modeling

# %% [markdown]
# # **Part 1: Data Collection & Curation**

# %% [markdown]
# **First we need to connect Google Colab with our Google Drive, so that we can have access to our Google drive within Colab.**
#
# This allows us to:
# * Save datasets
# * Reload data across sessions
# * Organize project files

# %%
from google.colab import drive
drive.mount('/content/gdrive/', force_remount=True)
# Out:
# Mounted at /content/gdrive/

# %% [markdown]
# **Now create "data" folder in our "Colab Notebooks" folder on Google Drive.**

# %%
! mkdir "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# mkdir: cannot create directory ‘/content/gdrive/My Drive/Colab Notebooks/data’: File exists

# %% [markdown]
# ## Install and Import Required Libraries
# We install the ChEMBL web service package so that we can retrieve bioactivity data

# %%
# !pip install chembl_webresource_client
# Out:
# Collecting chembl_webresource_client
#   Downloading chembl_webresource_client-0.10.9-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.5.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (2.32.4)
# Collecting requests-cache~=1.2 (from chembl_webresource_client)
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: easydict in /usr/local/lib/python3.12/dist-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.18.4->chembl_webresource_client) (2026.1.4)
# Requirement already satisfied: attrs>=21.2 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (25.4.0)
# Collecting cattrs>=22.2 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests-cache~=1.2->chembl_webresource_client) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache~=1.2->chembl_webresource_client)
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: typing-extensions>=4.14.0 in /usr/local/lib/python3.12/dist-packages (from cattrs>=22.2->requests-cache~=1.2->chembl_webresource_client) (4.15.0)
# Downloading chembl_webresource_client-0.10.9-py3-none-any.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.2/55.2 kB 2.0 MB/s eta 0:00:00
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 4.5 MB/s eta 0:00:00
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 5.7 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Installing collected packages: url-normalize, cattrs, requests-cache, chembl_webresource_client
# Successfully installed cattrs-25.3.0 chembl_webresource_client-0.10.9 requests-cache-1.2.1 url-normalize-2.2.1

# %% [markdown]
# # Import Libraries
# * pandas for data handling
# * new_client from chembl for accessing the database

# %%
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# # Step 1: Search for Traget Protein
#
# ## **Target Identification (PREB)**
# Search ChEMBL for the PREB target and select the most relevant entry.

# %%
target = new_client.target
target_query = target.search("PREB")
targets = pd.DataFrame.from_dict(target_query)
targets.head()
# Out:
#   cross_references      organism  \
# 0               []  Homo sapiens
# 1               []  Homo sapiens
# 2               []  Homo sapiens
# 3               []  Homo sapiens
# 4               []  Homo sapiens
#
#                                            pref_name  score  \
# 0                                         MHH-PREB-1   16.0
# 1             Nicotinamide phosphoribosyltransferase   12.0
# 2  Protein cereblon/Nicotinamide phosphoribosyltr...   11.0
# 3                      Stromal cell-derived factor 1   10.0
# 4  von Hippel-Lindau disease tumor suppressor/Nic...   10.0
#
#    species_group_flag target_chembl_id  \
# 0               False    CHEMBL2366127
# 1               False    CHEMBL1744525
# 2               False    CHEMBL6066026
# 3               False    CHEMBL3286074
# 4               False    CHEMBL5465234
#
#                                    target_components  \
# 0                                                 []
# 1  [{'accession': 'P43490', 'component_descriptio...
# 2  [{'accession': 'P43490', 'component_descriptio...
# 3  [{'accession': 'P48061', 'component_descriptio...
# 4  [{'accession': 'P43490', 'component_descriptio...
#
#                    target_type  tax_id
# 0                    CELL-LINE    9606
# 1               SINGLE PROTEIN    9606
# 2  PROTEIN-PROTEIN INTERACTION    9606
# 3               SINGLE PROTEIN    9606
# 4  PROTEIN-PROTEIN INTERACTION    9606

# %% [markdown]
# **Reterive Bioactivity data for selected target**

# %%
selected_target = targets.target_chembl_id[1]
selected_target
# Out:
# 'CHEMBL1744525'

# %% [markdown]
# **Now retrieve only bioactivity data for target; **MHH-PREB-1(CHEMBL1744525)** with reported IC 50  values in nM (nanomolar) unit.**

# %%
activity = new_client.activity
results = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df1 = pd.DataFrame.from_dict(results)
df1.head(5)
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      6152799                  []
# 1        None             None      6152800                  []
# 2        None             None      6274579                  []
# 3        None             None      6274580                  []
# 4        None             None      6274581                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1763209  Inhibition of human NAmPRTase by spectrophotom...
# 1   CHEMBL1763209  Inhibition of human NAmPRTase by spectrophotom...
# 2   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
# 3   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
# 4   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                        target_pref_name target_tax_id  \
# 0    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 1    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 2    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 3    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 4    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
#
#   text_value  toid  type units    uo_units upper_value   value
# 0       None  None  IC50    uM  UO_0000065        None    14.8
# 1       None  None  IC50    uM  UO_0000065        None    20.3
# 2       None  None  IC50    uM  UO_0000065        None  0.0019
# 3       None  None  IC50    uM  UO_0000065        None  0.0013
# 4       None  None  IC50    uM  UO_0000065        None  0.0042
#
# [5 rows x 46 columns]

# %%
df1.standard_type.unique()
# Out:
# array(['IC50'], dtype=object)

# %% [markdown]
# **Finally Save the resulting bioactivity data to a CSV file** **bioactivity_raw_data.csv**.

# %%
df1.to_csv('bioactivity_raw_data.csv', index=False)

# %% [markdown]
# **Now copy "bioactivity_raw_data.csv" file to Google Drive, in foler "data"**

# %%
! cp bioactivity_raw_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"

# %%
! ls -l "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# total 7600
# -rw------- 1 root root 7781931 Jan 29 11:17 bioactivity_raw_data.csv

# %%
! head bioactivity_raw_data.csv
# Out:
# action_type,activity_comment,activity_id,activity_properties,assay_chembl_id,assay_description,assay_type,assay_variant_accession,assay_variant_mutation,bao_endpoint,bao_format,bao_label,canonical_smiles,data_validity_comment,data_validity_description,document_chembl_id,document_journal,document_year,ligand_efficiency,molecule_chembl_id,molecule_pref_name,parent_molecule_chembl_id,pchembl_value,potential_duplicate,qudt_units,record_id,relation,src_id,standard_flag,standard_relation,standard_text_value,standard_type,standard_units,standard_upper_value,standard_value,target_chembl_id,target_organism,target_pref_name,target_tax_id,text_value,toid,type,units,uo_units,upper_value,value
# ,,6152799,[],CHEMBL1763209,Inhibition of human NAmPRTase by spectrophotometric analysis,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(/C=C/c1cccnc1)NCCCCC1CCN(C(=O)c2ccccc2)CC1,,,CHEMBL1759927,Eur J Med Chem,2011,"{'bei': '12.34', 'le': '0.23', 'lle': '0.90', 'sei': '7.75'}",CHEMBL566757,DAPORINAD,CHEMBL566757,4.83,0,http://www.openphacts.org/units/Nanomolar,1414675,=,1,1,=,,IC50,nM,,14800.0,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,14.8
# ,,6152800,[],CHEMBL1763209,Inhibition of human NAmPRTase by spectrophotometric analysis,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(/C=C/c1ccc[nH]1)NCCCCC1CCN(C(=O)c2ccccc2)CC1,,,CHEMBL1759927,Eur J Med Chem,2011,"{'bei': '12.36', 'le': '0.23', 'lle': '0.82', 'sei': '7.20'}",CHEMBL1762233,,CHEMBL1762233,4.69,0,http://www.openphacts.org/units/Nanomolar,1414678,=,1,1,=,,IC50,nM,,20300.0,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,20.3
# ,,6274579,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)=CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '20.77', 'le': '0.40', 'lle': '3.08', 'sei': '19.28'}",CHEMBL1801562,,CHEMBL1801562,8.72,0,http://www.openphacts.org/units/Nanomolar,1440747,=,1,1,=,,IC50,nM,,1.9,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.0019
# ,,6274580,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,O=C(NCc1cccnc1)c1ccc(N(Cc2ccccc2Cl)CC2CC2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '21.89', 'le': '0.42', 'lle': '3.81', 'sei': '19.65'}",CHEMBL1801561,,CHEMBL1801561,8.89,0,http://www.openphacts.org/units/Nanomolar,1440746,=,1,1,=,,IC50,nM,,1.3,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.0013
# ,,6274581,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,C#CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '21.48', 'le': '0.41', 'lle': '4.08', 'sei': '18.52'}",CHEMBL1801560,,CHEMBL1801560,8.38,0,http://www.openphacts.org/units/Nanomolar,1440745,=,1,1,=,,IC50,nM,,4.2,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.0042
# ,,6274582,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '19.47', 'le': '0.37', 'lle': '2.49', 'sei': '18.16'}",CHEMBL1801559,,CHEMBL1801559,8.21,0,http://www.openphacts.org/units/Nanomolar,1440744,=,1,1,=,,IC50,nM,,6.1,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.0061
# ,,6274583,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,CC(C)CN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '15.63', 'le': '0.30', 'lle': '1.05', 'sei': '14.10'}",CHEMBL1801558,,CHEMBL1801558,6.38,0,http://www.openphacts.org/units/Nanomolar,1440743,=,1,1,=,,IC50,nM,,420.0,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.42
# ,,6274584,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,CCCCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,,CHEMBL1801557,,CHEMBL1801557,,0,http://www.openphacts.org/units/Nanomolar,1440742,>,1,1,>,,IC50,nM,,10000.0,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,10.0
# ,,6274585,[],CHEMBL1805766,Inhibition of nicotinamide phosphoribosyltransferase-catalyzed conversion of nicotinamide to nicotinamide mononucleotide,B,,,BAO_0000190,BAO_0000357,single protein format,CCCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1,,,CHEMBL1800028,J Med Chem,2010,"{'bei': '19.86', 'le': '0.38', 'lle': '2.74', 'sei': '17.30'}",CHEMBL1801556,,CHEMBL1801556,7.82,0,http://www.openphacts.org/units/Nanomolar,1440741,=,1,1,=,,IC50,nM,,15.0,CHEMBL1744525,Homo sapiens,Nicotinamide phosphoribosyltransferase,9606,,,IC50,uM,UO_0000065,,0.015

# %% [markdown]
# # **Step 3: Bioactivity Data Retrieval (IC50)**
# **Retrieve bioactivity data (IC50) for the selected PREB target.**

# %% [markdown]
# **Inspect Missing Values**

# %%
df1["standard_type"].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# **Filter Rows with Valid Bioactivity Values**

# %%
df2 = df1[df1["standard_value"].notna()]
df2.head()
# Out:
#   action_type activity_comment  activity_id activity_properties  \
# 0        None             None      6152799                  []
# 1        None             None      6152800                  []
# 2        None             None      6274579                  []
# 3        None             None      6274580                  []
# 4        None             None      6274581                  []
#
#   assay_chembl_id                                  assay_description  \
# 0   CHEMBL1763209  Inhibition of human NAmPRTase by spectrophotom...
# 1   CHEMBL1763209  Inhibition of human NAmPRTase by spectrophotom...
# 2   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
# 3   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
# 4   CHEMBL1805766  Inhibition of nicotinamide phosphoribosyltrans...
#
#   assay_type assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0          B                    None                   None  BAO_0000190  ...
# 1          B                    None                   None  BAO_0000190  ...
# 2          B                    None                   None  BAO_0000190  ...
# 3          B                    None                   None  BAO_0000190  ...
# 4          B                    None                   None  BAO_0000190  ...
#
#   target_organism                        target_pref_name target_tax_id  \
# 0    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 1    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 2    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 3    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
# 4    Homo sapiens  Nicotinamide phosphoribosyltransferase          9606
#
#   text_value  toid  type units    uo_units upper_value   value
# 0       None  None  IC50    uM  UO_0000065        None    14.8
# 1       None  None  IC50    uM  UO_0000065        None    20.3
# 2       None  None  IC50    uM  UO_0000065        None  0.0019
# 3       None  None  IC50    uM  UO_0000065        None  0.0013
# 4       None  None  IC50    uM  UO_0000065        None  0.0042
#
# [5 rows x 46 columns]

# %% [markdown]
# **Assign Bioactivity Classes**
# Define active, intermediate, and inactive classes based on IC50 values.

# %%
bioactivity_class = []
for value in df2.standard_value:
    value = float(value)
    if value >= 10000:
        bioactivity_class.append("inactive")
    elif value <= 1000:
        bioactivity_class.append("active")
    else:
        bioactivity_class.append("intermediate")

# %% [markdown]
# **Extract Relevant Columns**

# %%
molecule_ids = df2.molecule_chembl_id.tolist()
canonical_smiles = df2.canonical_smiles.tolist()
standard_values = df2.standard_value.tolist()

# %%
data = list(zip(
    molecule_ids,
    canonical_smiles,
    standard_values,
        bioactivity_class,
))

# %% [markdown]
# **Create Preprocessed bioactivity Dataset**

# %%
df3 = pd.DataFrame(
    data,
    columns=[
        "molecule_chembl_id",
        "canonical_smiles",
        "standard_value",
        "bioactivity_class",
    ]
)
df3.head()
# Out:
#   molecule_chembl_id                                  canonical_smiles  \
# 0       CHEMBL566757    O=C(/C=C/c1cccnc1)NCCCCC1CCN(C(=O)c2ccccc2)CC1
# 1      CHEMBL1762233  O=C(/C=C/c1ccc[nH]1)NCCCCC1CCN(C(=O)c2ccccc2)CC1
# 2      CHEMBL1801562   CC(C)=CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1
# 3      CHEMBL1801561     O=C(NCc1cccnc1)c1ccc(N(Cc2ccccc2Cl)CC2CC2)cc1
# 4      CHEMBL1801560       C#CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1
#
#   standard_value bioactivity_class
# 0        14800.0          inactive
# 1        20300.0          inactive
# 2            1.9            active
# 3            1.3            active
# 4            4.2            active

# %% [markdown]
# **Remove Compounds without Valid SMILES**. Drop rows with **NaN**, **empty** or **None** SMILES values.

# %%
df3 = df3.dropna(subset=["canonical_smiles"])
df3 = df3[df3["canonical_smiles"].str.lower() != "none"]
df3 = df3[df3["canonical_smiles"].str.strip() != ""]
df3.head()
# Out:
#   molecule_chembl_id                                  canonical_smiles  \
# 0       CHEMBL566757    O=C(/C=C/c1cccnc1)NCCCCC1CCN(C(=O)c2ccccc2)CC1
# 1      CHEMBL1762233  O=C(/C=C/c1ccc[nH]1)NCCCCC1CCN(C(=O)c2ccccc2)CC1
# 2      CHEMBL1801562   CC(C)=CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1
# 3      CHEMBL1801561     O=C(NCc1cccnc1)c1ccc(N(Cc2ccccc2Cl)CC2CC2)cc1
# 4      CHEMBL1801560       C#CCN(Cc1ccccc1Cl)c1ccc(C(=O)NCc2cccnc2)cc1
#
#   standard_value bioactivity_class
# 0        14800.0          inactive
# 1        20300.0          inactive
# 2            1.9            active
# 3            1.3            active
# 4            4.2            active

# %% [markdown]
# **Save Preprocessed Bioactivity Data.** Save the cleaned dataset to CSV and copy to Google Drive.

# %%
df3.to_csv("bioactivity_preprocessed_data.csv", index=False)

# !cp bioactivity_preprocessed_data.csv "/content/gdrive/My Drive/Colab Notebooks/data"
# !ls "/content/gdrive/My Drive/Colab Notebooks/data"
# Out:
# bioactivity_preprocessed_data.csv  bioactivity_raw_data.csv

# %% [markdown]
# ## **End of Part 1: Data Collection and Curation**
